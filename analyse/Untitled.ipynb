# %%
import matplotlib.pyplot as plt
from PIL import Image
import cv2
import numpy as np
import glob

# %%
def detect_faces(image):
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    return faces

# Function to crop the image around the detected face
def crop_face(image, face_coordinates):
    x, y, w, h = face_coordinates
    return image[y:y+h, x:x+w]

# %%
base_images = glob.glob('/home/mzieba/Biometrics/arcface-pytorch/app/database/*')

# %%
imgs = [cv2.imread(b) for b in base_images]

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 8))

for i in range(4):
    ax[i].imshow(imgs[i][..., ::-1])

plt.show()
